# %%
ls
# Out:
# Capstone 1 Proposal.pdf   Housing_Wrangled.csv      test.csv
# DataStory.ipynb           Variable_Information.csv  test.png
# DataWrangleTest           data_description.txt      test2.png
# Data_Wrangling.ipynb      data_information.csv      train.csv
# Data_Wrangling.py         sample_submission.csv

# %%
#Import packages to be used
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Imports raw data
data = pd.read_csv('Housing_Wrangled.csv', index_col='Id')
data_information = pd.read_csv('data_information.csv', index_col='Column Name')

# %%
# Briefly looking at the data for ideas
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave  No Alley      Reg
# 2             20       RL         80.0     9600   Pave  No Alley      Reg
# 3             60       RL         68.0    11250   Pave  No Alley      IR1
# 4             70       RL         60.0     9550   Pave  No Alley      IR1
# 5             60       RL         84.0    14260   Pave  No Alley      IR1
# ...          ...      ...          ...      ...    ...       ...      ...
# 1456          60       RL         62.0     7917   Pave  No Alley      Reg
# 1457          20       RL         85.0    13175   Pave  No Alley      Reg
# 1458          70       RL         66.0     9042   Pave  No Alley      Reg
# 1459          20       RL         68.0     9717   Pave  No Alley      Reg
# 1460          20       RL         75.0     9937   Pave  No Alley      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea   PoolQC     Fence  \
# ...

# %% [markdown]
# Questions for starters:
#
# Which variables seem to affect sale price.
#
# Are there any items that can drastically improve value? (Either before or after a sale)

# %%
# Checking non-categorical variables for coorelation with sale price

# %%
data[list(data_information[data_information['Type'] == 'Numeric'].index)]
# Out:
#       LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1            65.0     8450            7            5       2003          2003
# 2            80.0     9600            6            8       1976          1976
# 3            68.0    11250            7            5       2001          2002
# 4            60.0     9550            7            5       1915          1970
# 5            84.0    14260            8            5       2000          2000
# ...           ...      ...          ...          ...        ...           ...
# 1456         62.0     7917            6            5       1999          2000
# 1457         85.0    13175            6            6       1978          1988
# 1458         66.0     9042            7            9       1941          2006
# 1459         68.0     9717            5            6       1950          1996
# 1460         75.0     9937            5            6       1965          1965
#
# ...

# %%
data_information
# Out:
#                               Type  \
# Column Name
# MSSubClass     Categorical Numeric
# MSZoning        Categorical String
# LotFrontage                Numeric
# LotArea                    Numeric
# Street          Categorical String
# ...                            ...
# MoSold         Categorical Numeric
# YrSold                     Numeric
# SaleType        Categorical String
# SaleCondition   Categorical String
# SalePrice                  Numeric
#
#                                            Category Distribution  Nan_count  \
# Column Name
# MSSubClass     ([20, 60, 50, 120, 30, 160, 70, 80, 90, 190, 8...        0.0
# MSZoning       (['RL', 'RM', 'FV', 'RH', 'C (all)'], [1151, 2...        0.0
# LotFrontage                                                  NaN        0.0
# LotArea                                                      NaN        0.0
# Street                             (['Pave', 'Grvl'], [1454, 6])        0.0
# ...

# %%
graphed_variables = list(data_information[data_information['Type'] == 'Numeric'].index)[0:5]
graphed_variables.append('SalePrice')
graphed_variables

sns.pairplot(data, vars=graphed_variables)
plt.show()

# %%
len(list(data_information[data_information['Type'] == 'Numeric'].index))
# Out:
# 35

# %%
graphed_variables = list(data_information[data_information['Type'] == 'Numeric'].index)[5:10]
graphed_variables.append('SalePrice')
graphed_variables

sns.pairplot(data, vars=graphed_variables)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
graphed_variables = list(data_information[data_information['Type'] == 'Numeric'].index)[10:15]
graphed_variables.append('SalePrice')
graphed_variables

sns.pairplot(data, vars=graphed_variables)
plt.show()

# %%
graphed_variables = list(data_information[data_information['Type'] == 'Numeric'].index)[15:20]
graphed_variables.append('SalePrice')
graphed_variables

sns.pairplot(data, vars=graphed_variables)
plt.show()

# %%
graphed_variables = list(data_information[data_information['Type'] == 'Numeric'].index)[20:25]
graphed_variables.append('SalePrice')
graphed_variables

sns.pairplot(data, vars=graphed_variables)
plt.show()

# %%
graphed_variables = list(data_information[data_information['Type'] == 'Numeric'].index)[25:30]
graphed_variables.append('SalePrice')
graphed_variables

sns.pairplot(data, vars=graphed_variables)
plt.show()

# %%
graphed_variables = list(data_information[data_information['Type'] == 'Numeric'].index)[30:35]
graphed_variables.append('SalePrice')
graphed_variables

sns.pairplot(data, vars=graphed_variables)
plt.show()
